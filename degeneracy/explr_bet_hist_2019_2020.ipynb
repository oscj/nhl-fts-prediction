# %%
import pandas as pd

# %%
nhl_odds = pd.read_csv('/Users/ojaimes/Documents/school/CMPUT466/nhl-over-under/degeneracy/bet_csvs/nhl_odds_2019_2020.csv')
nhl_odds
# Out:
#       Date  Rot VH        Team  1st  2nd  3rd  Final  Open  Close  PuckLine  \
# 0     1002    1  V      Ottawa    1    1    1      3   245    270       1.5
# 1     1002    2  H     Toronto    0    4    1      5  -300   -310      -1.5
# 2     1002    3  V  Washington    1    1    0      3   115    135       1.5
# 3     1002    4  H    St.Louis    2    0    0      2  -135   -150      -1.5
# 4     1002    5  V   Vancouver    0    1    1      2   105    116       1.5
# ...    ...  ... ..         ...  ...  ...  ...    ...   ...    ...       ...
# 2419   925   28  N      Dallas    2    1    1      4   140    135       1.5
# 2420   926   29  N      Dallas    1    0    1      3   145    150       1.5
# 2421   926   30  N    TampaBay    0    1    1      2  -166   -165      -1.5
# 2422   928    1  N    TampaBay    1    1    0      2  -161   -170      -1.5
# 2423   928    2  N      Dallas    0    0    0      0   141    155       1.5
#
# ...

# %%
closing_OU = nhl_odds["CloseOU"].to_list()
final_score = nhl_odds["Final"].to_list()

# %%
nhl_odds["CloseOU"].hist()
nhl_odds["Final"].hist()
# Out:
# <AxesSubplot:>
